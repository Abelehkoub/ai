# %%
import pandas as pd



# save filepath to variable for easier access


melbourne_file_path = 'd:/Git/AI/Kagel/melb_data.csv'
#melbourne_file_path = 'melb_data.csv'

# read the data and store data in DataFrame titled melbourne_data
#melbourne_data = pd.read_csv(melbourne_file_path, index_col="price")
melbourne_data = pd.read_csv(melbourne_file_path)

##melbourne_data.head()
##print(sum(melbourne_data('Price')))
# print a summary of the data in Melbourne data
melbourne_data.describe()
round(melbourne_data["Landsize"].mean())
melbourne_data.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
melbourne_data = melbourne_data.dropna(axis=0)

# %%
y = melbourne_data.Price

# %%
melbourne_features = ['Rooms', 'Bathroom', 'Landsize', 'Lattitude', 'Longtitude']

# %%
X = melbourne_data[melbourne_features]

# %%
X.describe()
# Out:
#              Rooms     Bathroom      Landsize    Lattitude   Longtitude
# count  6196.000000  6196.000000   6196.000000  6196.000000  6196.000000
# mean      2.931407     1.576340    471.006940   -37.807904   144.990201
# std       0.971079     0.711362    897.449881     0.075850     0.099165
# min       1.000000     1.000000      0.000000   -38.164920   144.542370
# 25%       2.000000     1.000000    152.000000   -37.855438   144.926198
# 50%       3.000000     1.000000    373.000000   -37.802250   144.995800
# 75%       4.000000     2.000000    628.000000   -37.758200   145.052700
# max       8.000000     8.000000  37000.000000   -37.457090   145.526350

# %%
X.head()
# Out:
#    Rooms  Bathroom  Landsize  Lattitude  Longtitude
# 1      2       1.0     156.0   -37.8079    144.9934
# 2      3       2.0     134.0   -37.8093    144.9944
# 4      4       1.0     120.0   -37.8072    144.9941
# 6      3       2.0     245.0   -37.8024    144.9993
# 7      2       1.0     256.0   -37.8060    144.9954

# %%
melbourne_data.Rooms
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 melbourne_data.Rooms(0)
#
# TypeError: 'Series' object is not callable

# %%
melbourne_data['Rooms']
# Out:
# 1        2
# 2        3
# 4        4
# 6        3
# 7        2
#         ..
# 12205    3
# 12206    3
# 12207    1
# 12209    2
# 12212    6
# Name: Rooms, Length: 6196, dtype: int64

# %%
import pandas as pd



# save filepath to variable for easier access


melbourne_file_path = 'd:/Git/AI/Kagel/melb_data.csv'
#melbourne_file_path = 'melb_data.csv'

# read the data and store data in DataFrame titled melbourne_data
#melbourne_data = pd.read_csv(melbourne_file_path, index_col="price")
melbourne_data = pd.read_csv(melbourne_file_path)

##melbourne_data.head()
##print(sum(melbourne_data('Price')))
# print a summary of the data in Melbourne data
melbourne_data.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  13580.000000  1.358000e+04  13580.000000  13580.000000  13580.000000
# mean       2.937997  1.075684e+06     10.137776   3105.301915      2.914728
# std        0.955748  6.393107e+05      5.868725     90.676964      0.965921
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.500000e+05      6.100000   3044.000000      2.000000
# 50%        3.000000  9.030000e+05      9.200000   3084.000000      3.000000
# 75%        3.000000  1.330000e+06     13.000000   3148.000000      3.000000
# max       10.000000  9.000000e+06     48.100000   3977.000000     20.000000
#
#            Bathroom           Car       Landsize  BuildingArea    YearBuilt  \
# count  13580.000000  13518.000000   13580.000000   7130.000000  8205.000000
# mean       1.534242      1.610075     558.416127    151.967650  1964.684217
# ...

# %%
melbourne_data.Price
# Out:
# 0        1480000.0
# 1        1035000.0
# 2        1465000.0
# 3         850000.0
# 4        1600000.0
#            ...
# 13575    1245000.0
# 13576    1031000.0
# 13577    1170000.0
# 13578    2500000.0
# 13579    1285000.0
# Name: Price, Length: 13580, dtype: float64

# %%
melbourne_data['Price']
# Out:
# 0        1480000.0
# 1        1035000.0
# 2        1465000.0
# 3         850000.0
# 4        1600000.0
#            ...
# 13575    1245000.0
# 13576    1031000.0
# 13577    1170000.0
# 13578    2500000.0
# 13579    1285000.0
# Name: Price, Length: 13580, dtype: float64

# %%
melbourne_data['Price'][0]
# Out:
# np.float64(1480000.0)

# %%
melbourne_data.iloc[1]
# Out:
# Suburb                      Abbotsford
# Address                25 Bloomburg St
# Rooms                                2
# Type                                 h
# Price                        1035000.0
# Method                               S
# SellerG                         Biggin
# Date                         4/02/2016
# Distance                           2.5
# Postcode                        3067.0
# Bedroom2                           2.0
# Bathroom                           1.0
# Car                                0.0
# Landsize                         156.0
# BuildingArea                      79.0
# YearBuilt                       1900.0
# CouncilArea                      Yarra
# Lattitude                     -37.8079
# Longtitude                    144.9934
# Regionname       Northern Metropolitan
# Propertycount                   4019.0
# Name: 1, dtype: object

# %%
melbourne_data.iloc[:,1]
# Out:
# 0            85 Turner St
# 1         25 Bloomburg St
# 2            5 Charles St
# 3        40 Federation La
# 4             55a Park St
#                ...
# 13575        12 Strada Cr
# 13576       77 Merrett Dr
# 13577         83 Power St
# 13578        96 Verdon St
# 13579          6 Agnes St
# Name: Address, Length: 13580, dtype: object

# %%
melbourne_data
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# ...

# %%
melbourne_data.iloc[:,1]
# Out:
# 0            85 Turner St
# 1         25 Bloomburg St
# 2            5 Charles St
# 3        40 Federation La
# 4             55a Park St
#                ...
# 13575        12 Strada Cr
# 13576       77 Merrett Dr
# 13577         83 Power St
# 13578        96 Verdon St
# 13579          6 Agnes St
# Name: Address, Length: 13580, dtype: object

# %%
melbourne_data.iloc[:4,1]
# Out:
# 0        85 Turner St
# 1     25 Bloomburg St
# 2        5 Charles St
# 3    40 Federation La
# Name: Address, dtype: object

# %%
melbourne_data.iloc[1:4,1]
# Out:
# 1     25 Bloomburg St
# 2        5 Charles St
# 3    40 Federation La
# Name: Address, dtype: object

# %%
melbourne_data.iloc[3:10,1]
# Out:
# 3      40 Federation La
# 4           55a Park St
# 5        129 Charles St
# 6          124 Yarra St
# 7         98 Charles St
# 8    6/241 Nicholson St
# 9         10 Valiant St
# Name: Address, dtype: object

# %%
melbourne_data.iloc[[5,7,9],1]
# Out:
# 5    129 Charles St
# 7     98 Charles St
# 9     10 Valiant St
# Name: Address, dtype: object

# %%
melbourne_data.iloc[-19:]
# Out:
#                   Suburb             Address  Rooms Type      Price Method  \
# 13561  Templestowe Lower           7 Dove Ct      4    h  1288000.0      S
# 13562          Thornbury     7 Ballantyne St      3    h  1450000.0      S
# 13563          Thornbury        201 Gooch St      3    h  1271000.0      S
# 13564        Tullamarine        7 Londrew Ct      3    h   540000.0      S
# 13565            Vermont      73 Nurlendi Rd      4    h  1263500.0      S
# 13566      Vermont South       9 Winswood Cl      4    h  1250000.0     PI
# 13567           Viewbank       149 Graham Rd      5    h  1316000.0     SP
# 13568           Wantirna  16 chesterfield Ct      4    h   951000.0      S
# 13569     Wantirna South        12 Armagh Cr      4    h  1323000.0      S
# 13570     Wantirna South       34 Fewster Dr      3    h   970000.0      S
# 13571     Wantirna South          15 Mara Cl      4    h  1330000.0      S
# ...

# %%
melbourne_data.loc[5,'Address']
# Out:
# '129 Charles St'

# %%
melbourne_data
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# ...

# %%
melbourne_data.loc[4,'Address']
# Out:
# '55a Park St'

# %%
melbourne_data.iloc[1:4,[1,2,3]]
# Out:
#             Address  Rooms Type
# 1   25 Bloomburg St      2    h
# 2      5 Charles St      3    h
# 3  40 Federation La      3    h

# %%
melbourne_data.loc[1:10,['Address','Rooms','Price']]
# Out:
#                Address  Rooms      Price
# 1      25 Bloomburg St      2  1035000.0
# 2         5 Charles St      3  1465000.0
# 3     40 Federation La      3   850000.0
# 4          55a Park St      4  1600000.0
# 5       129 Charles St      2   941000.0
# 6         124 Yarra St      3  1876000.0
# 7        98 Charles St      2  1636000.0
# 8   6/241 Nicholson St      1   300000.0
# 9        10 Valiant St      2  1097000.0
# 10  411/8 Grosvenor St      2   700000.0

# %%
melbourne_data.loc[:,['Address','Rooms','Price']]
# Out:
#                 Address  Rooms      Price
# 0          85 Turner St      2  1480000.0
# 1       25 Bloomburg St      2  1035000.0
# 2          5 Charles St      3  1465000.0
# 3      40 Federation La      3   850000.0
# 4           55a Park St      4  1600000.0
# ...                 ...    ...        ...
# 13575      12 Strada Cr      4  1245000.0
# 13576     77 Merrett Dr      3  1031000.0
# 13577       83 Power St      3  1170000.0
# 13578      96 Verdon St      4  2500000.0
# 13579        6 Agnes St      4  1285000.0
#
# [13580 rows x 3 columns]

# %%
melbourne_data.iloc[0:5]
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
melbourne_data.set_index("Suburb")
# Out:
#                         Address  Rooms Type      Price Method   SellerG  \
# Suburb
# Abbotsford         85 Turner St      2    h  1480000.0      S    Biggin
# Abbotsford      25 Bloomburg St      2    h  1035000.0      S    Biggin
# Abbotsford         5 Charles St      3    h  1465000.0     SP    Biggin
# Abbotsford     40 Federation La      3    h   850000.0     PI    Biggin
# Abbotsford          55a Park St      4    h  1600000.0     VB    Nelson
# ...                         ...    ...  ...        ...    ...       ...
# Wheelers Hill      12 Strada Cr      4    h  1245000.0      S     Barry
# Williamstown      77 Merrett Dr      3    h  1031000.0     SP  Williams
# Williamstown        83 Power St      3    h  1170000.0      S     Raine
# Williamstown       96 Verdon St      4    h  2500000.0     PI   Sweeney
# Yarraville           6 Agnes St      4    h  1285000.0     SP   Village
#
#                      Date  Distance  Postcode  Bedroom2  Bathroom  Car  \
# Suburb
# ...

# %%
melbourne_data.Rooms == '85 Turne *'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 13575    False
# 13576    False
# 13577    False
# 13578    False
# 13579    False
# Name: Address, Length: 13580, dtype: bool

# %%
melbourne_data.loc[melbourne_data.Rooms == 2]
# Out:
#                Suburb           Address  Rooms Type      Price Method  \
# 0          Abbotsford      85 Turner St      2    h  1480000.0      S
# 1          Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 5          Abbotsford    129 Charles St      2    h   941000.0      S
# 7          Abbotsford     98 Charles St      2    h  1636000.0      S
# 9          Abbotsford     10 Valiant St      2    h  1097000.0      S
# ...               ...               ...    ...  ...        ...    ...
# 13522  Port Melbourne     201 Stokes St      2    h  1515000.0     SP
# 13524         Prahran  17 Packington Pl      2    h  1365000.0      S
# 13530       Reservoir        92 Pine St      2    u   625500.0      S
# 13533   Ringwood East     14 Everard Rd      2    h   937000.0      S
# 13572        Watsonia     76 Kenmare St      2    h   650000.0     PI
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# ...

# %%
melbourne_data.loc[(melbourne_data.Rooms == 2) & (melbourne_data.Price <=100000)]
