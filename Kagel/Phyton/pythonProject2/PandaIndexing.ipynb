# %%
import pandas as pd



# save filepath to variable for easier access


file_path = 'D:\Git\Kagle_File/winemag-data-130k-v2.csv'
#melbourne_file_path = 'melb_data.csv'0000

# read the data and store data in DataFrame titled melbourne_data
#melbourne_data = pd.read_csv(melbourne_file_path, index_col="price")
reviews= pd.read_csv(file_path)

reviews.head()
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\G'
# <>:8: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\abelehkoub\AppData\Local\Temp\ipykernel_6944\2383430085.py:8: SyntaxWarning: invalid escape sequence '\G'
#   file_path = 'D:\Git\Kagle_File/winemag-data-130k-v2.csv'
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...

# %%
reviews.head()
# Out:
#    Unnamed: 0 country                                        description  \
# 0           0      US  This tremendous 100% varietal wine hails from ...
# 1           1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           2      US  Mac Watson honors the memory of a wine once ma...
# 3           3      US  This spent 20 months in 30% new French oak, an...
# 4           4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# ...

# %%
reviews.loc[0:10]
# Out:
#     Unnamed: 0 country                                        description  \
# 0            0      US  This tremendous 100% varietal wine hails from ...
# 1            1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2            2      US  Mac Watson honors the memory of a wine once ma...
# 3            3      US  This spent 20 months in 30% new French oak, an...
# 4            4  France  This is the top wine from La Bégude, named aft...
# 5            5   Spain  Deep, dense and pure from the opening bell, th...
# 6            6   Spain  Slightly gritty black-fruit aromas include a s...
# 7            7   Spain  Lush cedary black-fruit aromas are luxe and of...
# 8            8      US  This re-named vineyard was formerly bottled as...
# 9            9      US  The producer sources from two blocks of the vi...
# 10          10   Italy  Elegance, complexity and structure come togeth...
#
#                              designation  points  price            province  \
# ...

# %%
reviews.set_index("points")
# Out:
#         Unnamed: 0 country                                        description  \
# points
# 96               0      US  This tremendous 100% varietal wine hails from ...
# 96               1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 96               2      US  Mac Watson honors the memory of a wine once ma...
# 96               3      US  This spent 20 months in 30% new French oak, an...
# 95               4  France  This is the top wine from La Bégude, named aft...
# ...            ...     ...                                                ...
# 91          150925   Italy  Many people feel Fiano represents southern Ita...
# 91          150926  France  Offers an intriguing nose with ginger, lime an...
# 91          150927   Italy  This classic example comes from a cru vineyard...
# 90          150928  France  A perfect salmon shade, with scents of peaches...
# 90          150929   Italy  More Pinot Grigios should taste like this. A r...
#
# ...

# %%
reviews.loc[(melbourne_data.country == 'Italy')& (melbourne_data.points >= 90)]
# Out:
#         Unnamed: 0 country                                        description  \
# 10              10   Italy  Elegance, complexity and structure come togeth...
# 32              32   Italy  Underbrush, scorched earth, menthol and plum s...
# 35              35   Italy  Forest floor, tilled soil, mature berry and a ...
# 37              37   Italy  Aromas of forest floor, violet, red berry and ...
# 38              38   Italy  This has a charming nose that boasts rose, vio...
# ...            ...     ...                                                ...
# 150920      150920   Italy  Rich and mature aromas of smoke, earth and her...
# 150922      150922   Italy  Made by 30-ish Roberta Borghese high above Man...
# 150925      150925   Italy  Many people feel Fiano represents southern Ita...
# 150927      150927   Italy  This classic example comes from a cru vineyard...
# 150929      150929   Italy  More Pinot Grigios should taste like this. A r...
#
# ...

# %%
reviews.loc[(melbourne_data.country == 'Italy')| (melbourne_data.points >= 90)]
# Out:
#         Unnamed: 0 country                                        description  \
# 0                0      US  This tremendous 100% varietal wine hails from ...
# 1                1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2                2      US  Mac Watson honors the memory of a wine once ma...
# 3                3      US  This spent 20 months in 30% new French oak, an...
# 4                4  France  This is the top wine from La Bégude, named aft...
# ...            ...     ...                                                ...
# 150925      150925   Italy  Many people feel Fiano represents southern Ita...
# 150926      150926  France  Offers an intriguing nose with ginger, lime an...
# 150927      150927   Italy  This classic example comes from a cru vineyard...
# 150928      150928  France  A perfect salmon shade, with scents of peaches...
# 150929      150929   Italy  More Pinot Grigios should taste like this. A r...
#
# ...

# %%
melbourne_data.loc[melbourne_data.country.isin(['US','Spain'])]
# Out:
#         Unnamed: 0 country                                        description  \
# 0                0      US  This tremendous 100% varietal wine hails from ...
# 1                1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2                2      US  Mac Watson honors the memory of a wine once ma...
# 3                3      US  This spent 20 months in 30% new French oak, an...
# 5                5   Spain  Deep, dense and pure from the opening bell, th...
# ...            ...     ...                                                ...
# 150892      150892      US  A light, earthy wine, with violet, berry and t...
# 150896      150896      US  Some raspberry fruit in the aroma, but things ...
# 150914      150914      US  Old-gold in color, and thick and syrupy. The a...
# 150915      150915      US  Decades ago, Beringer’s then-winemaker Myron N...
# 150916      150916      US  An impressive wine that presents a full bouque...
#
# ...

# %%
reviews['critic']= 'everyone'
reviews
# Out:
#         Unnamed: 0 country                                        description  \
# 0                0      US  This tremendous 100% varietal wine hails from ...
# 1                1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2                2      US  Mac Watson honors the memory of a wine once ma...
# 3                3      US  This spent 20 months in 30% new French oak, an...
# 4                4  France  This is the top wine from La Bégude, named aft...
# ...            ...     ...                                                ...
# 150925      150925   Italy  Many people feel Fiano represents southern Ita...
# 150926      150926  France  Offers an intriguing nose with ginger, lime an...
# 150927      150927   Italy  This classic example comes from a cru vineyard...
# 150928      150928  France  A perfect salmon shade, with scents of peaches...
# 150929      150929   Italy  More Pinot Grigios should taste like this. A r...
#
# ...

# %%
reviews['index_backwards'] = range(len(reviews), 0, -1)
reviews['index_backwards']
# Out:
# 0         150930
# 1         150929
# 2         150928
# 3         150927
# 4         150926
#            ...
# 150925         5
# 150926         4
# 150927         3
# 150928         2
# 150929         1
# Name: index_backwards, Length: 150930, dtype: int64

# %%
reviews.groupby('points').points.count()
# Out:
# points
# 80       898
# 81      1502
# 82      4041
# 83      6048
# 84     10708
# 85     12411
# 86     15573
# 87     20747
# 88     17871
# 89     12921
# 90     15973
# 91     10536
# 92      9241
# 93      6017
# 94      3462
# 95      1716
# 96       695
# 97       365
# 98       131
# 99        50
# 100       24
# Name: points, dtype: int64

# %%
reviews.groupby('points').price.min()
# Out:
# points
# 80      5.0
# 81      5.0
# 82      4.0
# 83      4.0
# 84      4.0
# 85      4.0
# 86      4.0
# 87      5.0
# 88      6.0
# 89      7.0
# 90      8.0
# 91      7.0
# 92     11.0
# 93     12.0
# 94     13.0
# 95     20.0
# 96     20.0
# 97     35.0
# 98     50.0
# 99     44.0
# 100    80.0
# Name: price, dtype: float64

# %%
reviews_written = reviews.groupby('taster_twitter_handle').title.count()
reviews_written
# Out:
# taster_twitter_handle
# @AnneInVino          3685
# @JoeCz               5147
# @bkfiona               27
# @gordone_cellars     4177
# @kerinokeefe        10776
# @laurbuzz            1835
# @mattkettmann        6332
# @paulgwine           9532
# @suskostrzewa        1085
# @vboone              9537
# @vossroger          25514
# @wawinereport        4966
# @wineschach         15134
# @winewchristina         6
# @worldwineguys       1005
# Name: title, dtype: int64

# %%
reviews.groupby('price').points.max()
# Out:
# price
# 4.0       86
# 5.0       87
# 6.0       88
# 7.0       91
# 8.0       91
#           ..
# 1900.0    98
# 2000.0    97
# 2013.0    91
# 2500.0    96
# 3300.0    88
# Name: points, Length: 390, dtype: int64

# %%
reviews.groupby('variety').price.agg([min,max])
# Out:
# C:\Users\abelehkoub\AppData\Local\Temp\ipykernel_26944\622173761.py:1: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   reviews.groupby('variety').price.agg([min,max])
# C:\Users\abelehkoub\AppData\Local\Temp\ipykernel_26944\622173761.py:1: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   reviews.groupby('variety').price.agg([min,max])
#               min    max
# variety
# Abouriou     15.0   75.0
# Agiorgitiko  10.0   66.0
# Aglianico     6.0  180.0
# Aidani       27.0   27.0
# Airen         8.0   10.0
# ...           ...    ...
# Zinfandel     5.0  100.0
# Zlahtina     13.0   16.0
# Zweigelt      9.0   70.0
# ...

# %%
price_extremes = reviews.groupby('variety').price.agg(['min','max'])
# Out:
#               min    max
# variety
# Abouriou     15.0   75.0
# Agiorgitiko  10.0   66.0
# Aglianico     6.0  180.0
# Aidani       27.0   27.0
# Airen         8.0   10.0
# ...           ...    ...
# Zinfandel     5.0  100.0
# Zlahtina     13.0   16.0
# Zweigelt      9.0   70.0
# Çalkarası    19.0   19.0
# Žilavka      15.0   15.0
#
# [707 rows x 2 columns]

# %%
sorted_varieties =price_extremes.sort_values(by=['min','max'],ascending=False)
sorted_varieties
# Out:
#                                   min    max
# variety
# Ramisco                         495.0  495.0
# Terrantez                       236.0  236.0
# Francisa                        160.0  160.0
# Rosenmuskateller                150.0  150.0
# Tinta Negra Mole                112.0  112.0
# ...                               ...    ...
# Roscetto                          NaN    NaN
# Sauvignon Blanc-Sauvignon Gris    NaN    NaN
# Tempranillo-Malbec                NaN    NaN
# Vital                             NaN    NaN
# Zelen                             NaN    NaN
#
# [707 rows x 2 columns]

# %%
reviewer_mean_ratings = reviews.groupby('taster_name').points.mean()
reviewer_mean_ratings
# Out:
# taster_name
# Alexander Peartree    85.855422
# Anna Lee C. Iijima    88.415629
# Anne Krebiehl MW      90.562551
# Carrie Dykes          86.395683
# Christina Pickard     87.833333
# Fiona Adams           86.888889
# Jeff Jenssen          88.319756
# Jim Gordon            88.626287
# Joe Czerwinski        88.536235
# Kerin O’Keefe         88.867947
# Lauren Buzzeo         87.739510
# Matt Kettmann         90.008686
# Michael Schachner     86.907493
# Mike DeSimone         89.101167
# Paul Gregutt          89.082564
# Roger Voss            88.708003
# Sean P. Sullivan      88.755739
# Susan Kostrzewa       86.609217
# Virginie Boone        89.213379
# Name: points, dtype: float64

# %%
country_variety_counts = reviews.groupby(['country','variety']).count()
country_variety_counts
# Out:
#                                       Unnamed: 0  description  designation  \
# country   variety
# Argentina Barbera                              1            1            1
#           Bonarda                            105          105           69
#           Bordeaux-style Red Blend            89           89           83
#           Bordeaux-style White Blend           1            1            1
#           Cabernet Blend                       8            8            8
# ...                                          ...          ...          ...
# Uruguay   Tannat-Cabernet Franc                2            2            2
#           Tannat-Merlot                        6            6            4
#           Tannat-Syrah                         1            1            1
#           Tempranillo-Tannat                   1            1            1
#           White Blend                          1            1            1
#
# ...

# %%
country_variety_counts =reviews.groupby(['country','variety']).count()
country_variety_counts
# Out:
#                                       Unnamed: 0  description  designation  \
# country   variety
# Argentina Barbera                              1            1            1
#           Bonarda                            105          105           69
#           Bordeaux-style Red Blend            89           89           83
#           Bordeaux-style White Blend           1            1            1
#           Cabernet Blend                       8            8            8
# ...                                          ...          ...          ...
# Uruguay   Tannat-Cabernet Franc                2            2            2
#           Tannat-Merlot                        6            6            4
#           Tannat-Syrah                         1            1            1
#           Tempranillo-Tannat                   1            1            1
#           White Blend                          1            1            1
#
# ...

# %%
reviews.dtypes
# Out:
# Unnamed: 0                 int64
# country                   object
# description               object
# designation               object
# points                     int64
# price                    float64
# province                  object
# region_1                  object
# region_2                  object
# taster_name               object
# taster_twitter_handle     object
# title                     object
# variety                   object
# winery                    object
# dtype: object

# %%
reviews[pd.isnull(reviews.country)]
# Out:
#         Unnamed: 0 country                                        description  \
# 913            913     NaN  Amber in color, this wine has aromas of peach ...
# 3131          3131     NaN  Soft, fruity and juicy, this is a pleasant, si...
# 4243          4243     NaN  Violet-red in color, this semisweet wine has a...
# 9509          9509     NaN  This mouthwatering blend starts with a nose of...
# 9750          9750     NaN  This orange-style wine has a cloudy yellow-gol...
# ...            ...     ...                                                ...
# 124176      124176     NaN  This Swiss red blend is composed of four varie...
# 129407      129407     NaN  Dry spicy aromas of dusty plum and tomato add ...
# 129408      129408     NaN  El Capricho is one of Uruguay's more consisten...
# 129590      129590     NaN  A blend of 60% Syrah, 30% Cabernet Sauvignon a...
# 129900      129900     NaN  This wine offers a delightful bouquet of black...
#
# ...

# %%
reviews[pd.notnull(reviews.country)]
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
reviews.region_2.fillna("Unknown")
# Out:
# 0                   Unknown
# 1                   Unknown
# 2         Willamette Valley
# 3                   Unknown
# 4         Willamette Valley
#                 ...
# 129966              Unknown
# 129967         Oregon Other
# 129968              Unknown
# 129969              Unknown
# 129970              Unknown
# Name: region_2, Length: 129971, dtype: object

# %%
reviews.taster_twitter_handle.replace("@kerinokeefe", "@kerino")
# Out:
# 0             @kerino
# 1          @vossroger
# 2         @paulgwine
# 3                 NaN
# 4         @paulgwine
#              ...
# 129966            NaN
# 129967    @paulgwine
# 129968     @vossroger
# 129969     @vossroger
# 129970     @vossroger
# Name: taster_twitter_handle, Length: 129971, dtype: object

# %%
reviews[pd.isnull(reviews.price)]
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 13              13     Italy
# 30              30    France
# 31              31     Italy
# 32              32     Italy
# ...            ...       ...
# 129844      129844     Italy
# 129860      129860  Portugal
# 129863      129863  Portugal
# 129893      129893     Italy
# 129964      129964    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 13      This is dominated by oak and oak-driven aromas...
# 30      Red cherry fruit comes laced with light tannin...
# 31      Merlot and Nero d'Avola form the base for this...
# 32      Part of the extended Calanìca series, this Gri...
# ...                                                   ...
# 129844  Doga delle Clavule is a neutral, mineral-drive...
# 129860  This rich wine has a firm structure as well as...
# 129863  This mature wine that has 50% Touriga Nacional...
# ...

# %%
reviews[pd.isnull(reviews.price)].count()
# Out:
# Unnamed: 0               8996
# country                  8992
# description              8996
# designation              6310
# points                   8996
# price                       0
# province                 8992
# region_1                 7324
# region_2                  219
# taster_name              7248
# taster_twitter_handle    7199
# title                    8996
# variety                  8996
# winery                   8996
# dtype: int64

# %%
reviews.rename(columns={'points': 'score'})
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
reviews.rename(index={0: 'firstEntry', 1: 'secondEntry'})
# Out:
#              Unnamed: 0   country  \
# firstEntry            0     Italy
# secondEntry           1  Portugal
# 2                     2        US
# 3                     3        US
# 4                     4        US
# ...                 ...       ...
# 129966           129966   Germany
# 129967           129967        US
# 129968           129968    France
# 129969           129969    France
# 129970           129970    France
#
#                                                    description  \
# firstEntry   Aromas include tropical fruit, broom, brimston...
# secondEntry  This is ripe and fruity, a wine that is smooth...
# 2            Tart and snappy, the flavors of lime flesh and...
# 3            Pineapple rind, lemon pith and orange blossom ...
# 4            Much like the regular bottling from 2012, this...
# ...                                                        ...
# 129966       Notes of honeysuckle and cantaloupe sweeten th...
# ...

# %%
reviews.rename_axis("wines", axis='rows').rename_axis("fields", axis='columns')
# Out:
# fields  Unnamed: 0   country  \
# wines
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
# fields                                        description  \
# wines
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
canadian_youtube = pd.read_csv("D:\Git\Kagle_File/CAvideos.csv")

british_youtube = pd.read_csv("D:\Git\Kagle_File/GBvideos.csv")

pd.concat([canadian_youtube, british_youtube])
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# <>:3: SyntaxWarning: invalid escape sequence '\G'
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# <>:3: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\abelehkoub\AppData\Local\Temp\ipykernel_6944\1263043873.py:1: SyntaxWarning: invalid escape sequence '\G'
#   canadian_youtube = pd.read_csv("D:\Git\Kagle_File/CAvideos.csv")
# C:\Users\abelehkoub\AppData\Local\Temp\ipykernel_6944\1263043873.py:3: SyntaxWarning: invalid escape sequence '\G'
#   british_youtube = pd.read_csv("D:\Git\Kagle_File/GBvideos.csv")
#           video_id trending_date  \
# 0      n1WpP7iowLc      17.14.11
# 1      0dBIkQ4Mz1M      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      d380meD0W0M      17.14.11
# 4      2Vv-BfVoq4g      17.14.11
# ...            ...           ...
# 38911  l884wKofd54      18.14.06
# 38912  IP8k2xkhOdI      18.14.06
# 38913  Il-an3K9pjg      18.14.06
# 38914  -DRsfNObKIQ      18.14.06
# ...

# %%
left = canadian_youtube.set_index(['title', 'trending_date'])
right = british_youtube.set_index(['title', 'trending_date'])

left.join(right, lsuffix='_CAN', rsuffix='_UK')
# Out:
#                                                                  video_id_CAN  \
# title                                              trending_date
# Eminem - Walk On Water (Audio) ft. Beyoncé         17.14.11       n1WpP7iowLc
# PLUSH - Bad Unboxing Fan Mail                      17.14.11       0dBIkQ4Mz1M
# Racist Superman | Rudy Mancuso, King Bach & Lel... 17.14.11       5qpjK5DgCt4
# I Dare You: GOING BALD!?                           17.14.11       d380meD0W0M
# Ed Sheeran - Perfect (Official Music Video)        17.14.11       2Vv-BfVoq4g
# ...                                                                       ...
# HOW2: How to Solve a Mystery                       18.14.06       sGolxsMSGfQ
# Eli Lik Lik Episode 13 Partie 01                   18.14.06       8HNuRNi8t70
# KINGDOM HEARTS III – SQUARE ENIX E3 SHOWCASE 20... 18.14.06       GWlKEM3m2EE
# Trump Advisor Grovels To Trudeau                   18.14.06       lbMKLzQ4cNQ
# ...

# %%
ile_path = 'c/winemag-data-130k-v2.csv'
#melbourne_file_path = 'melb_data.csv'0000

# read the data and store data in DataFrame titled melbourne_data
#melbourne_data = pd.read_csv(melbourne_file_path, index_col="price")
reviews= pd.read_csv(file_path)

reviews.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\abelehkoub\AppData\Local\Temp\ipykernel_6944\2677944414.py:1: SyntaxWarning: invalid escape sequence '\G'
#   ile_path = 'D:\Git\Kagle_File/winemag-data-130k-v2.csv'
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...

# %%
reviews.rename(columns={'region_1': 'region','region_2': 'locale'})
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
reviews.rename(index='firstEntry')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 reviews.rename(index='firstEntry')
#
# File ~\PycharmProjects\pythonProject2\.venv\Lib\site-packages\pandas\core\frame.py:5767, in DataFrame.rename(self, mapper, index, columns, axis, copy, inplace, level, errors)
#    5636 def rename(
#    5637     self,
#    5638     mapper: Renamer | None = None,
#    (...)   5646     errors: IgnoreRaise = "ignore",
#    5647 ) -> DataFrame | None:
#    5648     """
#    5649     Rename columns or index labels.
#    5650
#    (...)   5765     4  3  6
#    5766     """
# -> 5767     return super()._rename(
#    5768         mapper=mapper,
#    5769         index=index,
#    5770         columns=columns,
#    5771         axis=axis,
#    5772         copy=copy,
#    5773         inplace=inplace,
#    5774         level=level,
#    5775         errors=errors,
# ...

# %%
gaming_products = pd.read_csv("D:\Git\Kagle_File/gaming.csv")
gaming_products['subreddit'] = "r/gaming"
movie_products = pd.read_csv("D:\Git\Kagle_File/movies.csv")
movie_products['subreddit'] = "r/movies"
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# <>:3: SyntaxWarning: invalid escape sequence '\G'
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# <>:3: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\abelehkoub\AppData\Local\Temp\ipykernel_6944\3210575852.py:1: SyntaxWarning: invalid escape sequence '\G'
#   gaming_products = pd.read_csv("D:\Git\Kagle_File/gaming.csv")
# C:\Users\abelehkoub\AppData\Local\Temp\ipykernel_6944\3210575852.py:3: SyntaxWarning: invalid escape sequence '\G'
#   movie_products = pd.read_csv("D:\Git\Kagle_File/movies.csv")
